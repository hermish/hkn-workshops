# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt # plotting
import seaborn as sns # aesthetics
# %config InlineBackend.figure_format = 'retina'

# %%
pokemon = pd.read_csv('pokemon.csv')
combats = pd.read_csv('combats.csv')
data = pd.DataFrame(combats)

for i in range(len(data)):
    id_1 = combats['First_pokemon'][i]
    id_2 = combats['Second_pokemon'][i]
    id_3 = combats['Winner'][i]
    
    for c in pokemon.columns[1:]:
        data.at[i, 'First_' + c] = pokemon[c][id_1 - 1]
        data.at[i, 'Second_' + c] = pokemon[c][id_2 - 1]
        data.at[i, 'Winner_' + c] = pokemon[c][id_3 - 1]

data.head(10)
# Out:
#    First_pokemon  Second_pokemon  Winner First_Name             Second_Name  \
# 0            266             298     298   Larvitar                 Nuzleaf
# 1            702             701     701   Virizion               Terrakion
# 2            191             668     668    Togetic                Beheeyem
# 3            237             683     683     Slugma               Druddigon
# 4            151             231     151    Omastar                 Shuckle
# 5            657             752     657     Joltik  Aegislash Shield Forme
# 6            192             134     134       Natu                    Jynx
# 7             73             545     545     Machop  Giratina Altered Forme
# 8            220             763     763     Pineco               Clauncher
# 9            302              31      31    Wingull                 Pikachu
#
#               Winner_Name First_Type 1 Second_Type 1 Winner_Type 1  \
# 0                 Nuzleaf         Rock         Grass         Grass
# 1               Terrakion        Grass          Rock          Rock
# 2                Beheeyem        Fairy       Psychic       Psychic
# 3               Druddigon         Fire        Dragon        Dragon
# 4                 Omastar         Rock           Bug          Rock
# 5                  Joltik          Bug         Steel           Bug
# 6                    Jynx      Psychic           Ice           Ice
# 7  Giratina Altered Forme     Fighting         Ghost         Ghost
# 8               Clauncher          Bug         Water         Water
# 9                 Pikachu        Water      Electric      Electric
#
#   First_Type 2        ...        Winner_Sp. Def First_Speed  Second_Speed  \
# 0       Ground        ...                  40.0        41.0          60.0
# 1     Fighting        ...                  90.0       108.0         108.0
# 2       Flying        ...                  95.0        40.0          40.0
# 3          NaN        ...                  90.0        20.0          48.0
# 4        Water        ...                  70.0        55.0           5.0
# 5     Electric        ...                  50.0        65.0          60.0
# 6       Flying        ...                  95.0        70.0          95.0
# 7          NaN        ...                 120.0        35.0          90.0
# 8          NaN        ...                  63.0        15.0          44.0
# 9       Flying        ...                  50.0        85.0          90.0
#
#    Winner_Speed  First_Generation  Second_Generation  Winner_Generation  \
# 0          60.0               2.0                3.0                3.0
# 1         108.0               5.0                5.0                5.0
# 2          40.0               2.0                5.0                5.0
# 3          48.0               2.0                5.0                5.0
# 4          55.0               1.0                2.0                1.0
# 5          65.0               5.0                6.0                5.0
# 6          95.0               2.0                1.0                1.0
# 7          90.0               1.0                4.0                4.0
# 8          44.0               2.0                6.0                6.0
# 9          90.0               3.0                1.0                1.0
#
#    First_Legendary  Second_Legendary  Winner_Legendary
# 0            False             False             False
# 1             True              True              True
# 2            False             False             False
# 3            False             False             False
# 4            False             False             False
# 5            False             False             False
# 6            False             False             False
# 7            False              True              True
# 8            False             False             False
# 9            False             False             False
#
# [10 rows x 36 columns]

# %%
data.to_csv('detailed_combats.csv', sep='\t', encoding='utf-8')
